# %%
lista = ["Hola",10, "Adios", [50,100,150]]
lista[-1]
# Out:
# [50, 100, 150]

# %%
lista[-1][0] ##aqui jala el 50
lista[-1][-1] ##aqui jala el 150
# Out:
# 150

# %%
for numero in lista[-1]:
    print(numero)
# Out:
# 50
# 100
# 150

# %%
matriz = [
    [8,  7,  0],
    [34, 2, -1],
    [5, -5, 12]
         ]

# %%
for i, fila in enumerate(matriz):
    for j, columna in enumerate(fila):
        if matriz[i][j] % 2 == 0:
            matriz[i][j] = 0
        else: 
            matriz[i][j] = 1
# Out:
# [[0, 1, 0], [0, 0, 1], [1, 1, 0]]
