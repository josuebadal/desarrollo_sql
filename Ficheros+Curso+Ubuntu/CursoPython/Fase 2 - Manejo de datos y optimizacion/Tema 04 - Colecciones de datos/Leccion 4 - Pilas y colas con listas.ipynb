# %%
pila = [3,4,5]
pila.append(6)
pila.append(7)
pila
# Out:
# [3, 4, 5, 6, 7]

# %%
pila.pop()
# Out:
# 7

# %%
pila
# Out:
# [3, 4, 5, 6]

# %%
n = pila.pop()
n
# Out:
# 6

# %%
pila
# Out:
# [3, 4, 5]

# %%
###ANTES DE USAR UNA COLA SE DEBE IMPORTAR LA LIBRERIA
from collections import deque

# %%
cola = deque()

# %%
cola
# Out:
# deque([])

# %%
cola = deque(['Hector','Juan','Miguel'])

# %%
cola
# Out:
# deque(['Hector', 'Juan', 'Miguel'])

# %%
cola.append('Maria')
cola.append('Arnaldo')

# %%
cola
# Out:
# deque(['Hector', 'Juan', 'Miguel', 'Maria', 'Arnaldo'])

# %%
###SACAR ELEMENTOS DE LAS COLAS
cola.popleft()
# Out:
# 'Hector'

# %%
cola
# Out:
# deque(['Juan', 'Miguel', 'Maria', 'Arnaldo'])

# %%
p = cola.popleft()

# %%
p
# Out:
# 'Juan'

# %%
cola
# Out:
# deque(['Miguel', 'Maria', 'Arnaldo'])
