# %%
vacio = {}

# %%
vacio
# Out:
# {}

# %%
type(vacio)
# Out:
# dict

# %%
colores = {'amarillo':'yellow','azul':'blue','verde':'green'}

# %%
colores
# Out:
# {'amarillo': 'yellow', 'azul': 'blue', 'verde': 'green'}

# %%
##como mandar a llamar el diccionario
colores['azul']
# Out:
# 'blue'

# %%
colores['amarillo']
# Out:
# 'yellow'

# %%
##dicionarios con numeros
numeros = {10:'diez',20:'veinte'}

# %%
numeros[10]
# Out:
# 'diez'

# %%
##modificar el contenido de un diccionario
colores['amarillo'] = 'white'

# %%
colores
# Out:
# {'amarillo': 'white', 'azul': 'blue', 'verde': 'green'}

# %%
## borrar clave y valor del diccionario
del(colores['amarillo'])

# %%
colores
# Out:
# {'azul': 'blue', 'verde': 'green'}

# %%
edades = {'Hector':27,'Juan':45,'Maria':34}

# %%
edades
# Out:
# {'Hector': 27, 'Juan': 45, 'Maria': 34}

# %%
##asignacion directa de edades
edades['Hector']+= 1
edades
# Out:
# {'Hector': 28, 'Juan': 45, 'Maria': 34}

# %%
##suma de elementos de un diccionario
edades['Juan'] + edades['Maria']
# Out:
# 79

# %%
##ciclo for con diccionarios
for edad in edades:
    print(edad)
# Out:
# Hector
# Juan
# Maria

# %%
## ciclo for para datos del diccionario
for clave in edades:
    print(edades[clave])
# Out:
# 28
# 45
# 34

# %%
## extracion de datos del diccionario con for
for clave in edades:
    print(clave,edades[clave])
# Out:
# Hector 28
# Juan 45
# Maria 34

# %%
##manera correcta de consultar un diccionario
for clave,valor in edades.items():
    print(clave,valor)
# Out:
# Hector 28
# Juan 45
# Maria 34

# %%
##DICCIONARIO DE DATOS JUNTO CON LISTAS
personajes = []

# %%
p = {'Nombre':'Gandalf','Clase':'Mago','Raza':'Humano'}

# %%
personajes.append(p)

# %%
personajes
# Out:
# [{'Nombre': 'Gandalf', 'Clase': 'Mago', 'Raza': 'Humano'}]

# %%
p = {'Nombre':'Legolas','Clase':'Arquero','Raza':'Elfo'}

# %%
personajes.append(p)

# %%
p = {'Nombre':'Gimli','Clase':'Guerraro','Raza':'Enano'}

# %%
personajes.append(p)

# %%
personajes
# Out:
# [{'Nombre': 'Gandalf', 'Clase': 'Mago', 'Raza': 'Humano'},
#  {'Nombre': 'Legolas', 'Clase': 'Arquero', 'Raza': 'Elfo'},
#  {'Nombre': 'Gimli', 'Clase': 'Guerraro', 'Raza': 'Enano'}]

# %%
## for para traer los datos de un diccionario
for p in personajes:
    print(p['Nombre'],p['Clase'],p['Raza'])
# Out:
# Gandalf Mago Humano
# Legolas Arquero Elfo
# Gimli Guerraro Enano

# %%
###EJERCICIO FINAL DEL CAPITULO
animales = {"caballo":"", "vaca":""}
animales
# Out:
# {'caballo': '', 'vaca': ''}

# %%
animales.update({
    "perro": "dog",
    "gato": "cat",
    "rana": "frog"
})
animales
# Out:
# {'caballo': '', 'vaca': '', 'perro': 'dog', 'gato': 'cat', 'rana': 'frog'}

# %%
animales['caballo'] = 'horse'
animales['vaca'] = 'cow'

del(animales['rana'])
del(animales['vaca'])
animales
# Out:
# {'caballo': 'horse', 'perro': 'dog', 'gato': 'cat'}
