# %%
valor = input()
# Out:
#  10

# %%
valor
# Out:
# '10'

# %%
valor = input()
# Out:
#  200

# %%
valor
# Out:
# '200'

# %%
valor = input("introduce un valor: ")
# Out:
# introduce un valor:  50

# %%
valor
# Out:
# '50'

# %%
valor = input("introduce un numero entero: ")
# Out:
# introduce un numero entero:  500

# %%
valor
# Out:
# '500'

# %%
valor = int(valor)

# %%
valor
# Out:
# 500

# %%
valor + 1000
# Out:
# 1500

# %%
valor = input("introduce un numero entero: ")
##DICE NUMERO ENTERO PERO EL 10.5 ES ENTERO
# Out:
# introduce un numero entero:  10.5

# %%
valor = float(valor)
valor
# Out:
# 10.5

# %%
##CASTEAR EL VALOR A FLOTANTE AL CAPTURARLO
valor = float(input("Introduce un numero decimal o entero: "))
# Out:
# Introduce un numero decimal o entero:  17.5

# %%
valor
# Out:
# 17.5

# %%
# Completa el ejercicio
nombre = input("Introduce tu nombre: ")
apellido = input("Introduce tu apellido: ")
edad = int(input("Cual es tu edad"))
numero_magico = float(input("ingresa un numero_magico"))
resultado = edad * numero_magico
cadena_final = nombre + " " + apellido + ": Tu número de la suerte es el " + str(resultado)
# Out:
# Introduce tu nombre:  badal
# Introduce tu apellido:  josue
# Cual es tu edad 31
# ingresa un numero_magico 1.2

# %%
print(cadena_final)
# Out:
# badal josue: Tu número de la suerte es el 37.199999999999996
