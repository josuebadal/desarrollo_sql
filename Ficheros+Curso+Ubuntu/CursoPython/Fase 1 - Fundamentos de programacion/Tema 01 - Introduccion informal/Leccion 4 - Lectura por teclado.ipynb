# %%
valor = input()
# Out:
#  .

# %%
valor
# Out:
# '.'

# %%
valor = input()
# Out:
#  100

# %%
valor
# Out:
# '100'

# %%
valor = input("introduce un valor: ")
# Out:
# introduce un valor:  100

# %%
valor
# Out:
# '100'

# %%
valor = input("introduce un numero entero: ")
# Out:
# introduce un numero entero:  500

# %%
valor
# Out:
# '500'

# %%
valor = int(valor)

# %%
valor
# Out:
# 500

# %%
valor + 1000
# Out:
# 1500

# %%
valor = input("introduce un numero entero: ")
# Out:
# introduce un numero entero:  10.5

# %%
valor = float(valor)
valor
# Out:
# 10.5

# %%
##CASTEAR EL VALOR A FLOTANTE AL CAPTURARLO
valor = float(input("Introduce un numero decimal o entero: "))
# Out:
# Introduce un numero decimal o entero:  20.5

# %%
valor
# Out:
# 20.5
