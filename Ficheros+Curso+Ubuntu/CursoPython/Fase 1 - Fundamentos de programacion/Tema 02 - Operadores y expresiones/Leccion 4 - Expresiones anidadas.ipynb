# %%
# completa el ejercicio
nombre = "Oscar"
edad = 15
valores = (nombre != "****") and (edad >= 10) and (edad <=18) and (len(nombre) >= 3) and (len(nombre) <= 10)
expresion = valores

expresion
# Out:
# True
