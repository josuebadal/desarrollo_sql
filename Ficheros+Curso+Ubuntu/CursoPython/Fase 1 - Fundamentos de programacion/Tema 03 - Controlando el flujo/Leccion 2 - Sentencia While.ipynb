# %%
c= 0
while c <= 5:
    c+=1
    print("c vale",c)
else:
    print("completado c vale",c)
# Out:
# c vale 1
# c vale 2
# c vale 3
# c vale 4
# c vale 5
# c vale 6
# completado c vale 6

# %%
c= 0
while c <= 5:
    c+=1
    if (c ==2):
        print("rompe bucle c vale",c)
        break
    print("c vale",c)
else:
    print("completado c vale",c)
# Out:
# c vale 1
# rompe bucle c vale 2

# %%
c= 0
while c <= 5:
    c+=1
    if (c ==4):
        print("se salta interacion",c)
        continue
    print("c vale",c)
else:
    print("completado c vale",c)
# Out:
# c vale 1
# c vale 2
# c vale 3
# se salta interacion 4
# c vale 5
# c vale 6
# completado c vale 6

# %%
print("menu unteractivo")
while(True):
    print("""escribe una opcion
    1 saludar
    2 sumar dos numeros
    3 salir""")
    opcion = input()
    if opcion == '1':
        print("hola")
    elif opcion == '2':
        n1 = float(input("numero1"))
        n2 = float(input("numero2"))
        print("la suma es: ", n1+n2)
    elif opcion == '3':
        print("adios")
        break
    else:
        print("Comando desconocido,vuelve a intentarlo")
# Out:
# menu unteractivo
# escribe una opcion
#     1 saludar
#     2 sumar dos numeros
#     3 salir
#  3
# adios

# %%
numero = int(input("introduce numero entero"))
while numero % 5 !=0:
    numero = int(input("no es multiplo, introduce un numero"))
print("correcto, es multiplo de 5")
# Out:
# introduce numero entero 7
# no es multiplo, introduce un numero 7
# no es multiplo, introduce un numero 8
# no es multiplo, introduce un numero 9
# no es multiplo, introduce un numero 10
# correcto, es multiplo de 5
