# %%
elementos = ["Hola",4,"Adios",[1,2,3]]

for e in elementos:
    print(e)
# Out:
# Hola
# 4
# Adios
# [1, 2, 3]

# %%
from evaluate import numero
 
# Completa el ejercicio aquí
sumatorio = 0
 
# Generamos el bucle entre 0 y el numero+1 (para no excluirlo del range)
for n in range(numero+1):
    # Si no es múltiple de 5 y 7 lo sumamos
    if n % 5 != 0 and n % 7 != 0:
        sumatorio += n
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from evaluate import numero
#       2
#       3 # Completa el ejercicio aquí
#       4 sumatorio = 0
#
# ModuleNotFoundError: No module named 'evaluate'

# %%
a,b,c = 10,50,100
print(a,b,c)
# Out:
# 10 50 100

# %%
(a,b,c) = (11,51,101)
print(a,b,c)
# Out:
# 11 51 101

# %%
[a,b,c] = [12,52,102]
a,b,c
# Out:
# (12, 52, 102)

# %%
def function():
    return 13,53,103
a,b,c = function()

# %%
a,b,c
# Out:
# (13, 53, 103)

# %%
list(enumerate(elementos))
# Out:
# [(0, 'Hola'), (1, 4), (2, 'Adios'), (3, [1, 2, 3])]

# %%
for tupla in enumerate(elementos):
    print(tupla)
# Out:
# (0, 'Hola')
# (1, 4)
# (2, 'Adios')
# (3, [1, 2, 3])

# %%
for indice,valor in enumerate(elementos):
    print(indice,valor)
# Out:
# 0 Hola
# 1 4
# 2 Adios
# 3 [1, 2, 3]

# %%
from evaluate import iniciales
for i,cadena in enumerate(iniciales):
    iniciales[i] = iniciales[i][0]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 from evaluate import iniciales
#
# ModuleNotFoundError: No module named 'evaluate'

# %%
numero = int(input("Introduce un numero entero entre 1 y 9: "))

while numero < 1 or numero > 9:
    numero = int(input("Introduce un numero valido"))    

multiplos = list(range(numero,101,numero))
# Out:
# Introduce un numero entero entre 1 y 9:  0
# Introduce un numero valido -45
# Introduce un numero valido 10
# Introduce un numero valido 5

# %%
# Out:
# 0
