# %%
if not False:
    print("se cumple la condicion")
    print("tambien se muestre este print")
# Out:
# se cumple la condicion
# tambien se muestre este print

# %%
a = 5
if a == 2:
    print("a vale 2")
if a == 5:
    print("a vale 5")
# Out:
# a vale 5

# %%
a = 5
b = 10
if a == 5 :
    print("a vale",a)
    if b == 10:
        print("y b vale",b)
# Out:
# a vale 5
# y b vale 10

# %%
if a == 5 and b ==10:
    print("a vale 5 y b vale 10")
# Out:
# a vale 5 y b vale 10

# %%
n = 10
if n %2  == 0:
    print(n,"es numero par")
else:
    print(n,"es numero impar")
# Out:
# 10 es numero par

# %%
comando = "SALUDAR"
if comando == "ENTRAR":
    print("bienvenido")
elif comando == "SALUDAR":
    print("hola")
elif comando == "SALIR":
    print("saliendo")
else:
    print("comando no reconocido")
# Out:
# hola

# %%
nota = float(input("introduce nota"))
if nota >= 9:
    print("sobresaliente")
elif nota >= 7:
    print("notable")
elif nota >= 6:
    print("bien")
elif nota >= 5: 
    print("suficiente")
else:
    print("insuficiente")
# Out:
# introduce nota 10
# sobresaliente

# %%
c1 = input("agrega una cadena")
c2 = input("agrega una cadena2")
resultado = 0

if len(c1) > len(c2):
    resultado = 1
    print(resultado)
elif len(c1) < len(c2):
    resultado = 2
    print(resultado)
else:
    resultado = 0
    print(resultado)
# Out:
# agrega una cadena cinco
# agrega una cadena2 uno
# 1
